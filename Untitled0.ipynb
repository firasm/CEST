# %%
import sarpy

# %%
h1= sarpy.Experiment('herS1').find_adata_scans()

# %%
h1
# Out:
# {u'auc60': [['herS1Lo02.2e1/19'],
#   ['herS1Lo02B.2g1/14'],
#   ['herS1Lo03.2e1/17'],
#   ['herS1Lo04.2e1/14'],
#   ['herS1Ls01.2e1/18'],
#   ['herS1Ls02.2g1/14'],
#   ['herS1Ls03.2f1/14'],
#   ['herS1Ls05.2e1/15'],
#   ['herS1Mo02.251/14'],
#   ['herS1Mo03.251/17'],
#   ['herS1Mo04.271/17'],
#   ['herS1Mo05.271/17'],
#   ['herS1Mo06.2g1/14'],
#   ['herS1Ms02.251/18'],
#   ['herS1Ms03.271/17'],
#   ['herS1Ms04.271/17'],
#   ['herS1Ms05.271/17'],
#   ['herS1Ms06.2g1/13'],
#   ['herS1So02.2m1/14'],
#   ['herS1So03.2n1/14'],
#   ['herS1So04.2m1/14'],
#   ['herS1So05.2n1/14'],
#   ['herS1Ss01.2m1/14'],
#   ['herS1Ss02.2m1/14'],
#   ['herS1Ss03.2n1/14'],
#   ['herS1Ss04.2m1/14'],
#   ['herS1Ss06.2n1/14']],
#  u'roi': [['herS1Lo01.2g1/4'],
#   ['herS1Lo02.2e1/6'],
#   ['herS1Lo02B.2g1/4'],
#   ['herS1Lo03.2e1/4'],
#   ['herS1Lo04.2e1/4'],
#   ['herS1Ls01.2e1/5'],
#   ['herS1Ls02.2g1/4'],
#   ['herS1Ls03.2f1/4'],
#   ['herS1Ls05.2e1/5'],
#   ['herS1Mo02.251/4'],
#   ['herS1Mo03.251/4'],
# ...
