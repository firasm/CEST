# %%
import sarpy
import numpy
import os
import pylab
import glob
import sarpy.fmoosvi.analysis
import copy

# %%
mask = imread(os.path.expanduser("~/sdata/sketchy/mas.tif"))
def rgb2gray(rgb):

    r, g, b = rgb[:,:,0], rgb[:,:,1], rgb[:,:,2]
    gray = 0.2989 * r + 0.5870 * g + 0.1140 * b

    return gray

mask = rgb2gray(mask)

# %%
subplot(121)
pylab.imshow(a[:,:,2])
subplot(122)
boolmask = mask.copy()

boolmask[boolmask>253] = 0
boolmask[boolmask!=0] = 1

pylab.imshow(boolmask)

# %%
imdata = []

path = "~/sdata/sketchy/tiffs/"

os.chdir(os.path.expanduser(path))
for files in glob.glob("*.tif"):
    imdata.append(rgb2gray(imread(files)))
imdata = numpy.array(imdata)

# %%
pylab.imshow(imdata[6,:,:] * boolmask)
