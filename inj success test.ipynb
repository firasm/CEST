# %%
import sarpy
import sarpy.fmoosvi.getters

hers10 = sarpy.Experiment('HerS11Bs15')
dce = hers10.find_scan_by_protocol('.*DCE.*')
print dce
# Out:
# WARNING:sarpy.io.BRUKER_classes:Directory "/Users/fmoosvi/bdata/stefan/nmr/HerS11Bs15.me1/11" did not contain processed data (2dseq)
# [Scan object: Scan("HerS11Bs15.me1/6")
#    protocol: 06_FLASH2D.6sl-DCE
#    TE = [2.6696]
#    TR = [51]
#    FA = 40
#    FoV = [4.2624, 2.1312]
#    matrix = [256, 64], Scan object: Scan("HerS11Bs15.me1/9")
#    protocol: 06_FLASH2D.6sl-DCE
#    TE = [2.6696]
#    TR = [51]
#    FA = 40
#    FoV = [4.2624, 2.1312]
#    matrix = [256, 64], Scan object: Scan("HerS11Bs15.me1/11")
#    protocol: 06_FLASH2D.6sl-DCE
#    TE = [2.6696]
#    TR = [51]
#    FA = 40
#    FoV = [4.2624, 2.1312]
#    matrix = [256, 64]]

# %% [markdown]
# ### Allegedly an "HPG" enhancement curve

# %%
sarpy.fmoosvi.getters.get_fid_enhancement(dce[-3].shortdirname)
print dce[-3].shortdirname
# Out:
# HerS11Bs15.me1/6

# %% [markdown]
# ### An Omniscan enhancement curve

# %%
sarpy.fmoosvi.getters.get_fid_enhancement(dce[-1].shortdirname)
print dce[-1].shortdirname
# Out:
# WARNING:sarpy.io.BRUKER_classes:Directory "/Users/fmoosvi/bdata/stefan/nmr/HerS11Bs15.me1/11" did not contain processed data (2dseq)
# WARNING:sarpy.io.BRUKERIO:size(fid) = 5678720 != 18186240.0 = ACQ_size*NR
# WARNING:sarpy.io.BRUKERIO:NR reset to 115
# HerS11Bs15.me1/11
